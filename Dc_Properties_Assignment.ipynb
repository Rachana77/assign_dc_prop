# %% [markdown]
# # Assignment 1

# %%
import pandas as pd
import numpy as np

filename = "DC_Properties.csv"
df = pd.read_csv(filename)

df.head()
# Out:
#    ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  \
# 0   0       4          0      Warm Cool  Y        2.0      8      4  1910.0
# 1   1       3          1      Warm Cool  Y        2.0     11      5  1898.0
# 2   2       3          1  Hot Water Rad  Y        2.0      9      5  1910.0
# 3   3       3          1  Hot Water Rad  Y        2.0      8      5  1900.0
# 4   4       2          1      Warm Cool  Y        1.0     11      3  1913.0
#
#    YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
dupe = df.duplicated()

# %%
df.loc[dupe]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df.columns
# Out:
# Index(['ID', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df[df['HF_BATHRM'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['NUM_UNITS'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['BEDRM'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['AYB'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 3252      3252       2          1     Forced Air  Y        2.0      7      3
# 4034      4034       3          0  Hot Water Rad  N        2.0     16      5
# 4302      4302       2          0     Forced Air  Y        1.0      7      3
# 4922      4922       2          2     Forced Air  Y        2.0     10      6
# 5126      5126       4          0     Forced Air  Y        4.0      8      4
# 5213      5213       4          1     Forced Air  Y        1.0     10      4
# 5786      5786       2          1      Warm Cool  Y        1.0      7      3
# 6145      6145       1          1     Forced Air  Y        1.0      5      2
# 6355      6355       1          1     Forced Air  Y        1.0      6      3
# 6891      6891       7          0     Forced Air  Y        3.0     13      7
# 7554      7554       2          1  Hot Water Rad  Y        1.0      8      3
# ...

# %%
df[df['YR_RMDL'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 5            5       3          2  Hot Water Rad  Y        1.0     10      5
# 11          11       5          0  Hot Water Rad  Y        3.0     16      6
# 39          39       3          1      Warm Cool  Y        2.0      9      4
# 47          47       2          1     Forced Air  N        2.0      9      4
# 48          48       2          1     Forced Air  N        2.0      8      3
# 49          49       3          1      Warm Cool  Y        2.0      8      3
# 50          50       2          1     Forced Air  Y        2.0      8      3
# 57          57       1          0  Hot Water Rad  Y        1.0      6      3
# 67          67       1          0     Forced Air  Y        1.0      6      2
# 74          74       2          1      Warm Cool  Y        2.0     11      4
# 75          75       2          1      Warm Cool  Y        2.0     11      3
# ...

# %%
df[df['STORIES'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 1148      1148       5          0  Forced Air  Y        2.0     11      5
# 3506      3506       3          1  Forced Air  Y        2.0      7      2
# 3516      3516       4          2  Forced Air  Y        1.0     14      6
# 4397      4397       2          1  Forced Air  Y        1.0      7      2
# 4406      4406       3          0  Forced Air  Y        1.0      9      4
# 4575      4575       4          2  Forced Air  Y        2.0     10      4
# 5105      5105       3          0  Forced Air  Y        1.0      8      4
# 6124      6124      10          2  Forced Air  Y        2.0     23     11
# 6125      6125      10          2  Forced Air  Y        2.0     23     11
# 8465      8465       2          1  Forced Air  0        1.0      8      5
# 8908      8908       2          1  Forced Air  Y        1.0      8      4
# 14676    14676       3          0  Forced Air  Y        1.0      6      3
# ...

# %%
df[df['SALEDATE'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 10          10       3          0     Forced Air  N        3.0     12      5
# 12          12       2          0  Hot Water Rad  N        2.0      9      5
# 13          13       2          0      Warm Cool  Y        2.0     11      5
# 15          15       2          1      Warm Cool  Y        2.0      9      4
# 26          26       1          0  Hot Water Rad  N        1.0     10      5
# 30          30       2          1     Forced Air  Y        2.0      8      3
# 33          33       2          1     Forced Air  Y        2.0     10      3
# 36          36       3          1      Warm Cool  Y        2.0     10      4
# 38          38       3          1     Forced Air  Y        2.0      9      4
# 39          39       3          1      Warm Cool  Y        2.0      9      4
# ...

# %%
df[df['PRICE'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
# 11          11       5          0  Hot Water Rad  Y        3.0     16      6
# 12          12       2          0  Hot Water Rad  N        2.0      9      5
# 13          13       2          0      Warm Cool  Y        2.0     11      5
# 15          15       2          1      Warm Cool  Y        2.0      9      4
# 17          17       2          0  Hot Water Rad  N        1.0      6      3
# 18          18       3          1  Hot Water Rad  Y        2.0     10      4
# ...

# %%
df[df['QUALIFIED'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['SALE_NUM'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['GBA'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['BLDG_NUM'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['STYLE'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['STRUCT'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['GRADE'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['CNDTN'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['EXTWALL'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['ROOF'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['INTWALL'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# 106707  106707       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['KITCHENS'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 100629  100629       2          1  Forced Air  Y        1.0      6      3
# 106696  106696       2          0  Forced Air  Y        NaN      4      2
# 106697  106697       2          0  Forced Air  Y        NaN      4      2
# 106698  106698       2          0  Forced Air  Y        NaN      4      2
# 106699  106699       2          0  Forced Air  Y        NaN      4      2
# 106700  106700       2          0  Forced Air  Y        NaN      4      2
# 106701  106701       2          0  Forced Air  Y        NaN      4      2
# 106702  106702       2          0  Forced Air  Y        NaN      4      2
# 106703  106703       2          0  Forced Air  Y        NaN      4      2
# 106704  106704       2          0  Forced Air  Y        NaN      4      2
# 106705  106705       2          0  Forced Air  Y        NaN      4      2
# 106706  106706       2          0  Forced Air  Y        NaN      4      2
# ...

# %%
df[df['FIREPLACES'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['USECODE'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['LANDAREA'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['GIS_LAST_MOD_DTTM'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['SOURCE'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['CMPLX_NUM'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0            0       4          0      Warm Cool  Y        2.0      8      4
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 2            2       3          1  Hot Water Rad  Y        2.0      9      5
# 3            3       3          1  Hot Water Rad  Y        2.0      8      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 5            5       3          2  Hot Water Rad  Y        1.0     10      5
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 7            7       3          1  Hot Water Rad  Y        2.0      8      4
# 8            8       3          1      Warm Cool  Y        2.0      7      3
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
# ...

# %%
df[df['LIVING_GBA'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0            0       4          0      Warm Cool  Y        2.0      8      4
# 1            1       3          1      Warm Cool  Y        2.0     11      5
# 2            2       3          1  Hot Water Rad  Y        2.0      9      5
# 3            3       3          1  Hot Water Rad  Y        2.0      8      5
# 4            4       2          1      Warm Cool  Y        1.0     11      3
# 5            5       3          2  Hot Water Rad  Y        1.0     10      5
# 6            6       1          0      Warm Cool  Y        2.0      5      2
# 7            7       3          1  Hot Water Rad  Y        2.0      8      4
# 8            8       3          1      Warm Cool  Y        2.0      7      3
# 9            9       1          1  Hot Water Rad  Y        1.0      6      2
# 10          10       3          0     Forced Air  N        3.0     12      5
# ...

# %%
df[df['FULLADDRESS'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 540        540       3          1      Warm Cool  Y        1.0      9      4
# 1426      1426       2          1     Forced Air  Y        1.0      6      4
# 1449      1449       4          2     Forced Air  Y        2.0     10      4
# 1492      1492       2          1     Forced Air  Y        1.0      4      2
# 2108      2108       3          0      Warm Cool  Y        2.0      6      4
# 2109      2109       3          1      Warm Cool  Y        2.0      8      4
# 2758      2758       2          1  Hot Water Rad  N        2.0      8      3
# 2961      2961       2          1     Forced Air  Y        1.0      9      4
# 3727      3727       4          0  Hot Water Rad  N        4.0     16      7
# 3816      3816       2          1     Forced Air  Y        1.0      6      2
# 3817      3817       1          1  Hot Water Rad  Y        1.0      6      2
# ...

# %%
df[df['CITY'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 1426      1426       2          1     Forced Air  Y        1.0      6      4
# 1449      1449       4          2     Forced Air  Y        2.0     10      4
# 1492      1492       2          1     Forced Air  Y        1.0      4      2
# 2108      2108       3          0      Warm Cool  Y        2.0      6      4
# 2109      2109       3          1      Warm Cool  Y        2.0      8      4
# 2758      2758       2          1  Hot Water Rad  N        2.0      8      3
# 3727      3727       4          0  Hot Water Rad  N        4.0     16      7
# 3816      3816       2          1     Forced Air  Y        1.0      6      2
# 3817      3817       1          1  Hot Water Rad  Y        1.0      6      2
# 3862      3862       3          1     Forced Air  Y        1.0      6      4
# 4034      4034       3          0  Hot Water Rad  N        2.0     16      5
# ...

# %%
df[df['STATE'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 1426      1426       2          1     Forced Air  Y        1.0      6      4
# 1449      1449       4          2     Forced Air  Y        2.0     10      4
# 1492      1492       2          1     Forced Air  Y        1.0      4      2
# 2108      2108       3          0      Warm Cool  Y        2.0      6      4
# 2109      2109       3          1      Warm Cool  Y        2.0      8      4
# 2758      2758       2          1  Hot Water Rad  N        2.0      8      3
# 3727      3727       4          0  Hot Water Rad  N        4.0     16      7
# 3816      3816       2          1     Forced Air  Y        1.0      6      2
# 3817      3817       1          1  Hot Water Rad  Y        1.0      6      2
# 3862      3862       3          1     Forced Air  Y        1.0      6      4
# 4034      4034       3          0  Hot Water Rad  N        2.0     16      5
# ...

# %%
df[df['ZIPCODE'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104610  104610       2          0  Hot Water Rad  N        2.0     11      4
#
#            AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD  \
# 104610  1938.0      NaN   ...           NaN              NaN
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK  WARD  SQUARE   X   Y  \
# 104610                NaN           NaN          NaN   NaN    PAR  NaN NaN
#
#        QUADRANT
# 104610      NaN
#
# [1 rows x 49 columns]

# %%
df[df['NATIONALGRID'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 1426      1426       2          1     Forced Air  Y        1.0      6      4
# 1449      1449       4          2     Forced Air  Y        2.0     10      4
# 1492      1492       2          1     Forced Air  Y        1.0      4      2
# 2108      2108       3          0      Warm Cool  Y        2.0      6      4
# 2109      2109       3          1      Warm Cool  Y        2.0      8      4
# 2758      2758       2          1  Hot Water Rad  N        2.0      8      3
# 3727      3727       4          0  Hot Water Rad  N        4.0     16      7
# 3816      3816       2          1     Forced Air  Y        1.0      6      2
# 3817      3817       1          1  Hot Water Rad  Y        1.0      6      2
# 3862      3862       3          1     Forced Air  Y        1.0      6      4
# 4034      4034       3          0  Hot Water Rad  N        2.0     16      5
# ...

# %%
df[df['LATITUDE'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104610  104610       2          0  Hot Water Rad  N        2.0     11      4
#
#            AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD  \
# 104610  1938.0      NaN   ...           NaN              NaN
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK  WARD  SQUARE   X   Y  \
# 104610                NaN           NaN          NaN   NaN    PAR  NaN NaN
#
#        QUADRANT
# 104610      NaN
#
# [1 rows x 49 columns]

# %%
df[df['LONGITUDE'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104610  104610       2          0  Hot Water Rad  N        2.0     11      4
#
#            AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD  \
# 104610  1938.0      NaN   ...           NaN              NaN
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK  WARD  SQUARE   X   Y  \
# 104610                NaN           NaN          NaN   NaN    PAR  NaN NaN
#
#        QUADRANT
# 104610      NaN
#
# [1 rows x 49 columns]

# %%
df[df['ASSESSMENT_NBHD'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104610  104610       2          0  Hot Water Rad  N        2.0     11      4
#
#            AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD  \
# 104610  1938.0      NaN   ...           NaN              NaN
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK  WARD  SQUARE   X   Y  \
# 104610                NaN           NaN          NaN   NaN    PAR  NaN NaN
#
#        QUADRANT
# 104610      NaN
#
# [1 rows x 49 columns]

# %%
df[df['ASSESSMENT_SUBNBHD'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 92          92       2          0  Hot Water Rad  N        1.0      7      4
# 93          93       2          3  Hot Water Rad  N        1.0     12      6
# 257        257       1          1     Forced Air  Y        1.0      4      2
# 258        258       1          1     Forced Air  Y        1.0      4      2
# 259        259       2          0     Forced Air  Y        2.0      6      3
# 260        260       2          0  Hot Water Rad  N        2.0      6      2
# 261        261       1          0     Forced Air  Y        1.0      6      2
# 262        262       3          0      Warm Cool  Y        3.0      9      3
# 263        263       2          1     Forced Air  Y        1.0      5      3
# 264        264       1          0  Hot Water Rad  N        1.0      6      3
# 265        265       1          1      Warm Cool  Y        1.0      5      2
# ...

# %%
df[df['CENSUS_TRACT'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104610  104610       2          0  Hot Water Rad  N        2.0     11      4
#
#            AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD  \
# 104610  1938.0      NaN   ...           NaN              NaN
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK  WARD  SQUARE   X   Y  \
# 104610                NaN           NaN          NaN   NaN    PAR  NaN NaN
#
#        QUADRANT
# 104610      NaN
#
# [1 rows x 49 columns]

# %%
df[df['CENSUS_BLOCK'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 1426      1426       2          1     Forced Air  Y        1.0      6      4
# 1449      1449       4          2     Forced Air  Y        2.0     10      4
# 1492      1492       2          1     Forced Air  Y        1.0      4      2
# 2108      2108       3          0      Warm Cool  Y        2.0      6      4
# 2109      2109       3          1      Warm Cool  Y        2.0      8      4
# 2758      2758       2          1  Hot Water Rad  N        2.0      8      3
# 3727      3727       4          0  Hot Water Rad  N        4.0     16      7
# 3816      3816       2          1     Forced Air  Y        1.0      6      2
# 3817      3817       1          1  Hot Water Rad  Y        1.0      6      2
# 3862      3862       3          1     Forced Air  Y        1.0      6      4
# 4034      4034       3          0  Hot Water Rad  N        2.0     16      5
# ...

# %%
df[df['WARD'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104610  104610       2          0  Hot Water Rad  N        2.0     11      4
#
#            AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD  \
# 104610  1938.0      NaN   ...           NaN              NaN
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK  WARD  SQUARE   X   Y  \
# 104610                NaN           NaN          NaN   NaN    PAR  NaN NaN
#
#        QUADRANT
# 104610      NaN
#
# [1 rows x 49 columns]

# %%
df[df['SQUARE'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df[df['X'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104586  104586       5          1      Warm Cool  Y        1.0     13      5
# 104587  104587       3          1     Forced Air  Y        1.0      7      3
# 104588  104588       4          0  Hot Water Rad  N        1.0     10      4
# 104589  104589       3          0     Forced Air  Y        1.0     11      4
# 104590  104590       3          2      Warm Cool  Y        1.0     16      4
# 104591  104591       3          2      Warm Cool  Y        1.0     12      3
# 104592  104592       4          1      Warm Cool  Y        1.0     10      5
# 104593  104593       3          1  Hot Water Rad  N        1.0      9      3
# 104594  104594       3          0      Warm Cool  Y        1.0      7      3
# 104595  104595       3          0      Warm Cool  Y        1.0      9      3
# 104596  104596       5          1      Warm Cool  Y        1.0     13      4
# ...

# %%
df[df['Y'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104586  104586       5          1      Warm Cool  Y        1.0     13      5
# 104587  104587       3          1     Forced Air  Y        1.0      7      3
# 104588  104588       4          0  Hot Water Rad  N        1.0     10      4
# 104589  104589       3          0     Forced Air  Y        1.0     11      4
# 104590  104590       3          2      Warm Cool  Y        1.0     16      4
# 104591  104591       3          2      Warm Cool  Y        1.0     12      3
# 104592  104592       4          1      Warm Cool  Y        1.0     10      5
# 104593  104593       3          1  Hot Water Rad  N        1.0      9      3
# 104594  104594       3          0      Warm Cool  Y        1.0      7      3
# 104595  104595       3          0      Warm Cool  Y        1.0      9      3
# 104596  104596       5          1      Warm Cool  Y        1.0     13      4
# ...

# %%
df[df['QUADRANT'].isnull()]
# Out:
#             ID  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 104586  104586       5          1      Warm Cool  Y        1.0     13      5
# 104587  104587       3          1     Forced Air  Y        1.0      7      3
# 104588  104588       4          0  Hot Water Rad  N        1.0     10      4
# 104589  104589       3          0     Forced Air  Y        1.0     11      4
# 104590  104590       3          2      Warm Cool  Y        1.0     16      4
# 104591  104591       3          2      Warm Cool  Y        1.0     12      3
# 104592  104592       4          1      Warm Cool  Y        1.0     10      5
# 104593  104593       3          1  Hot Water Rad  N        1.0      9      3
# 104594  104594       3          0      Warm Cool  Y        1.0      7      3
# 104595  104595       3          0      Warm Cool  Y        1.0      9      3
# 104596  104596       5          1      Warm Cool  Y        1.0     13      4
# ...

# %%
df['PRICE'].fillna(df['PRICE'].mean(), inplace=True)

# %%
df[df['PRICE'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df.dropna(subset=['ZIPCODE','WARD'], inplace=True)

# %%
df[df['ZIPCODE'].isnull()]
